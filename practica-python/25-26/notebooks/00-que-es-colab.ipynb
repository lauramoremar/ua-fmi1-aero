# %% [markdown]
# # Introducción a Google Colab

# %% [markdown]
# ## 1. ¿Qué es y por qué se usa Google Colab?
# Google Colaboratory ("Google Colab"), es un servicio gratuito en la nube proporcionado por Google.
# Permite a los usuarios escribir y ejecutar código Python a través del navegador, sin necesidad de ninguna configuración previa. Es muy popular por varias razones:
#
# - **No requiere configuración**: Puedes escribir y ejecutar un script de Python sin preocuparte por instalar Python o cualquier biblioteca en tu sistema.
# - **Colaboración y Compartir**: Te permite compartir tus cuadernos y colaborar con otros en tiempo real.
# - **Acceso gratuito a GPU**: Google Colab ofrece acceso gratuito a GPU.
# - **Entorno de Codificación Interactivo**: Google Colab proporciona un entorno de codificación interactivo, similar a Jupyter Notebook, donde puedes escribir código y ver la salida, escribir texto en markdown para documentación y visualizar datos.
# - **Control de versiones**

# %% [markdown]
# ## 2. Acceder y crear un Notebook
#
# * Desde Google Drive: Crear archivo -> Más -> Google Colaboratory
# * Siguiendo el link: https://colab.research.google.com/
# * Una vez dentro: Archivo -> Nuevo
#
#
# ### Colab es una instancia temporal
# * Colab es una instancia temporal. Si generas información o archivos, deberás exportarlos de algun modo pues no se va a guardar

# %% [markdown]
# ## 3. Interfaz básica

# %% [markdown]
# ### Tipos de celdas
#
# Cada cuaderno o notebook de Google Colab se basa en Celdas, en las cuales puedes colocar código o texto

# %%
# CELDA DE CODIGO
# Es con fondo gris, tiene botón de play al lado
# Se puede ejecutar

# %% [markdown]
# **CELDA DE TEXTO**
#
# Cuando la editas puedes ir viendo como quedando en el lado derecho
#
# Acepta lenguaje Markdown
# * **Este texto está en negrita**
# * *Este texto está en cursiva*
# * Todo esto es una lista
#
# Si se te olvida algo, puedes ver la barra de arriba.

# %% [markdown]
# Imprescindible:
# * Añadir celdas, moverlas, eliminarlas (con las opciones de arriba o bien contr+m b crea nueva celda, o contrl+m d elimina la celda sobre la que estas).
# * Ejecutar una celda python: boton de "play" o shift+enter/ contr+enter.
# * Flujo de ejecución (cuidado!)

# %% [markdown]
# ## Ejecutar código y entorno de python
#
# * Celdas tipo Código
# * Desactivaremos IA Assistant (para un mejor aprendizaje)

# %%
# Si eres novato en python puede ser que te ocurra algo como esto

print = "hola mundo"

# %% [markdown]
# Si querías imprimir "hola mundo", este código está mal. Pero no solo eso, si no que va a topar con un nombre protegido. De modo tal que vas a generar un error cuando intentes correr el código bueno

# %%
print("hola mundo")

# %% [markdown]
# Para solucionarlo, deberás ir a Runtime > Restart runtime. Esto reinicia la maquina, eliminando toda la información.

# %% [markdown]
# ## 4. Guardar, descargar y compartir el Notebook
#
# * Guardar copia en Google Drive.
# * Descargar -> .ipynb (descarga el cuaderno tal cuál)
# * Descargar -> .py (descarga el archivo .py)

# %% [markdown]
# ## 5. Consejos Rápidos
# * Ejecutar en orden
# * No borrar celdas donde se importan librerías
# * Guardar siempre el Notebook en Google Drive (si no, desaparecen todos los cambios)
